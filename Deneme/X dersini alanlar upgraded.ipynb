# %%
def X_Taken_students(df_ , Subj):
    new_df = pd.DataFrame(columns=['ID','Student_Level','Subj','Section'])
    rowCount=len(df_.index)
    for i in range (rowCount):
        if(df_.iat[i,2]== Subj):
            id_stu=df_.iat[i,0]
            for k in range (rowCount):
                if(i != k and df_.iat[k,0]==id_stu):
                    new_df=new_df.append(df_.loc[[k]],ignore_index=True) 
    new_df=new_df.sort_values('Subj')
    new_df=new_df.reset_index(drop=True)                
    return new_df

def Classes_Students(new_df_):           
    list_sub_nms=[]                      #dictinary mi yapsam?
    list_ppl_count=[]
    prev=''

    for i in range (len(new_df_)):
        x= new_df_.iat[i,2]
        if(x != prev):
            list_sub_nms.append(x)
            list_ppl_count.append(1)
            prev=x
        else:
            temp=list_sub_nms.index(x)
            list_ppl_count[temp]=list_ppl_count[temp]+1

    Combiined_List= pd.DataFrame ({'Subj': list_sub_nms,'Total_Students':list_ppl_count})
    Combiined_List=Combiined_List.sort_values('Total_Students',ascending=False)
    Combiined_List=Combiined_List.reset_index(drop=True)
    return Combiined_List

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

file = r'C:\Users\umut\Desktop\Proje\FirstPart_200801.xlsx'
df = pd.read_excel(file, sheet_name='Sheet1')

df=df.drop(columns=['Term','Max Capacity','Enrollment'])

df['Subj'] =df['Subj'].astype(str) + ' ' + df['Numb'].astype(str) #delete space
df.drop(columns=['Numb'],inplace=True)

sort_by_ID=df.sort_values('ID')
sort_by_ID=sort_by_ID.reset_index(drop=True)

# %%
sort_by_Subj=df.sort_values('Subj')                         #subj_nm  => names of subjects
subj_nm=[sort_by_Subj.iat[0,2]]
prev=subj_nm[0]
rowCount=len(df.index)

for i in range (rowCount):
    if(prev != sort_by_Subj.iat[i,2]):
        prev=sort_by_Subj.iat[i,2]
        subj_nm.append(prev)

# %%
AAAA=X_Taken_students(df , subj_nm[0])     #subj_nm de 0. dersi alanlar
Group=Classes_Students(AAAA)
#Burda 1 tane ortakları vb sil
#Sonra 


SUBJ=Group.iat[0,0]      #if [0,1]>..  yüzde ve kişi sayısı

AAAA2=X_Taken_students(AAAA,SUBJ)
Group2=Classes_Students(AAAA2)

# %%
BBBB=X_Taken_students(AAAA2,Group2.iat[0,0])
BBBB2=X_Taken_students(BBBB,Group2.iat[1,0])
Group3=Classes_Students(BBBB2)
print(Group2)
print(Group3)
# Out:
#          Subj  Total_Students
# 0    SPS 303D              17
# 1     SPS 303              17
# 2    FIN 301R              12
# 3     FIN 301              12
# 4     ORG 301              11
# 5    MGMT 409              10
# 6    HUM 202D               8
# 7     HUM 202               8
# 8    MGMT 407               8
# 9   OPIM 302R               8
# 10   OPIM 302               8
# 11    ARA 301               5
# 12    SPA 101               5
# 13   MKTG 301               5
# 14    ORG 302               5
# 15  MATH 203R               4
# 16    ITA 101               4
# 17   MATH 203               4
# 18    RUS 101               4
# 19    SPA 201               4
# 20   HART 433               4
# 21   HUM 212D               3
# 22   MKTG 406               3
# 23   MKTG 402               3
# 24  ECON 201R               3
# 25   ECON 201               3
# 26    HUM 212               3
# 27   MGMT 401               2
# 28    HUM 211               2
# 29    ACC 405               2
# ..        ...             ...
# 45  OPIM 301R               1
# 46    TLL 301               1
# 47    ARA 303               1
# 48    CIP 101               1
# 49    CIP 201               1
# 50   CULT 201               1
# 51   HIST 227               1
# 52     IR 342               1
# 53   POLS 495               1
# 54   HART 414               1
# 55    ITA 201               1
# 56   ECON 301               1
# 57  ECON 301R               1
# 58    ITA 301               1
# 59   OPIM 301               1
# 60   MATH 306               1
# 61    MS 309R               1
# 62     MS 309               1
# 63    MS 302R               1
# 64     MS 302               1
# 65   MATH 201               1
# 66   ECON 450               1
# 67    ENS 208               1
# 68   ENS 208R               1
# 69  MATH 201R               1
# 70   MGMT 404               1
# 71  MGMT 201R               1
# 72   MGMT 201               1
# 73  MATH 306R               1
# 74     VA 333               1
#
# [75 rows x 2 columns]
# 75
#          Subj  Total_Students
# 0     ORG 301               7
# 1     FIN 301               7
# 2    FIN 301R               7
# 3    HUM 202D               4
# 4     ORG 302               4
# 5    MKTG 301               4
# 6     HUM 202               4
# 7     ARA 301               3
# 8   OPIM 302R               3
# 9    OPIM 302               3
# 10    SPA 201               2
# 11    SPA 101               2
# 12    RUS 101               2
# 13   MGMT 409               2
# 14   MGMT 407               2
# 15    HUM 212               2
# 16   HUM 212D               2
# 17   HART 433               2
# 18    HUM 204               1
# 19    FRE 101               1
# 20    TLL 301               1
# 21   CULT 201               1
# 22   ECON 201               1
# 23  ECON 201R               1
# 24   POLS 495               1
# 25   ECON 301               1
# 26  ECON 301R               1
# 27   ECON 330               1
# 28  ECON 330R               1
# 29   MKTG 406               1
# 30    FRE 201               1
# 31   HUM 204D               1
# 32    GER 201               1
# 33  MGMT 201R               1
# 34   MGMT 201               1
# 35  MATH 203R               1
# 36   MATH 203               1
# 37  MATH 201R               1
# 38   MATH 201               1
# 39    ITA 201               1
# 40    CIP 201               1
# 41    HUM 211               1
# 42     VA 333               1

# %%
def isInside(CL,p):
    for i in range (len(CL)):
        k=0
        while(p[k] in CL[i]):
            k=k+1
            if(k==len(p)):
                return True
    return False     

Clusters=[]    #in cluster append => example: Clusters=[[1,2,8],[1,3],[1,4]]    if you try to add 4,1 or 1,8 it should NOT add!! 


def RecursiveFunc(b_subj,pth,df_f,k):
    
    pth.append(subj_nm.index(b_subj))
    k=k+1
    
    b_df = X_Taken_students(df_f , b_subj)
    Rem_Class= Classes_Students(b_df)
    Rem_Class= Rem_Class[Rem_Class["Total_Students"] > 10]   #Remove rows which has less than 10 students 
    Rem_Class= Rem_Class.reset_index(drop=True)              #DONT FORGET to add % with or cond. to upper line

    if(len(Rem_Class.index)== 0 or len(pth)== 10):           #If none left in Rem_Class or pth length reached 10 quit recursion
        #dont continue
        if(len(pth)!=1 or not isInside(Clusters,pth)):
            Clusters.append(pth)                             #add path to Clusters       ### Check if exists though ###
    
    else:
        for t in range (len(Rem_Class.index)):
            RecursiveFunc(Rem_Class.iat[t,0],pth,b_df,k)
            
    return
        


for i in range (len(subj_nm)):
    base_subj = subj_nm[i]
    path=[]
    
    RecursiveFunc(base_subj,path,df,0)
        
        
Clusters
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-ef8c10f8020d> in <module>()
#      30     path=[]
#      31
# ---> 32     RecursiveFunc(base_subj,path,df,0      )
#      33
#      34
#
# <ipython-input-53-ef8c10f8020d> in RecursiveFunc(b_subj, pth, df_f, k)
#      20     else:
#      21         for t in range (len(Rem_Class.index)):
# ---> 22             RecursiveFunc(Rem_Class.iat[t,0],pth,b_df,k)
#      23
#      24     return
#
# <ipython-input-53-ef8c10f8020d> in RecursiveFunc(b_subj, pth, df_f, k)
#      20     else:
#      21         for t in range (len(Rem_Class.index)):
# ---> 22             RecursiveFunc(Rem_Class.iat[t,0],pth,b_df,k)
#      23
#      24     return
#
# <ipython-input-53-ef8c10f8020d> in RecursiveFunc(b_subj, pth, df_f, k)
#      20     else:
#      21         for t in range (len(Rem_Class.index)):
# ---> 22             RecursiveFunc(Rem_Class.iat[t,0],pth,b_df,k)
#      23
#      24     return
#
# <ipython-input-53-ef8c10f8020d> in RecursiveFunc(b_subj, pth, df_f, k)
#      20     else:
#      21         for t in range (len(Rem_Class.index)):
# ---> 22             RecursiveFunc(Rem_Class.iat[t,0],pth,b_df,k)
#      23
#      24     return
#
# <ipython-input-53-ef8c10f8020d> in RecursiveFunc(b_subj, pth, df_f, k)
#      20     else:
#      21         for t in range (len(Rem_Class.index)):
# ---> 22             RecursiveFunc(Rem_Class.iat[t,0],pth,b_df,k)
#      23
#      24     return
#
# <ipython-input-53-ef8c10f8020d> in RecursiveFunc(b_subj, pth, df_f, k)
#      20     else:
#      21         for t in range (len(Rem_Class.index)):
# ---> 22             RecursiveFunc(Rem_Class.iat[t,0],pth,b_df,k)
#      23
#      24     return
#
# <ipython-input-53-ef8c10f8020d> in RecursiveFunc(b_subj, pth, df_f, k)
#      20     else:
#      21         for t in range (len(Rem_Class.index)):
# ---> 22             RecursiveFunc(Rem_Class.iat[t,0],pth,b_df,k)
#      23
#      24     return
#
# <ipython-input-53-ef8c10f8020d> in RecursiveFunc(b_subj, pth, df_f, k)
#      20     else:
#      21         for t in range (len(Rem_Class.index)):
# ---> 22             RecursiveFunc(Rem_Class.iat[t,0],pth,b_df,k)
#      23
#      24     return
#
# <ipython-input-53-ef8c10f8020d> in RecursiveFunc(b_subj, pth, df_f, k)
#      20     else:
#      21         for t in range (len(Rem_Class.index)):
# ---> 22             RecursiveFunc(Rem_Class.iat[t,0],pth,b_df,k)
#      23
#      24     return
#
# <ipython-input-53-ef8c10f8020d> in RecursiveFunc(b_subj, pth, df_f, k)
#       9     k=k+1
#      10
# ---> 11     b_df = X_Taken_students(df_f , b_subj)
#      12     Rem_Class= Classes_Students(b_df)
#      13     Rem_Class= Rem_Class[Rem_Class["Total_Students"] > 10]   #Remove rows which has less than 10 students
#
# <ipython-input-28-4f131de70499> in X_Taken_students(df_, Subj)
#       7             for k in range (rowCount):
#       8                 if(i != k and df_.iat[k,0]==id_stu):
# ----> 9                     new_df=new_df.append(df_.loc[[k]],ignore_index=True)
#      10     new_df=new_df.sort_values('Subj')
#      11     new_df=new_df.reset_index(drop=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1614                     raise ValueError('Cannot index with multidimensional key')
#    1615
# -> 1616                 return self._getitem_iterable(key, axis=axis)
#    1617
#    1618             # nested tuple slicing
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1113
#    1114         if self._should_validate_iterable(axis):
# -> 1115             self._has_valid_type(key, axis)
#    1116
#    1117         labels = self.obj._get_axis(axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1464
#    1465                 # True indicates missing values
# -> 1466                 missing = ax.get_indexer_for(key) < 0
#    1467
#    1468                 if np.any(missing):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer_for(self, target, **kwargs)
#    2823         """
#    2824         if self.is_unique:
# -> 2825             return self.get_indexer(target, **kwargs)
#    2826         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#    2827         return indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2700                                  'backfill or nearest reindexing')
#    2701
# -> 2702             indexer = self._engine.get_indexer(target._values)
#    2703
#    2704         return _ensure_platform_int(indexer)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.lookup()
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     422
#     423
# --> 424 def asarray(a, dtype=None, order=None):
#     425     """Convert the input to an array.
#     426
#
# KeyboardInterrupt:
